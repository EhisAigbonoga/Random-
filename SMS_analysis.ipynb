# %% [markdown]
# ## Analysis of SMS Data

# %%
require(tidyverse)
require(data.table)

# %% [raw]
# df <- read_csv("Impact of Short Messaging Service (SMS) Based Interventions on Medication Adherence Among Clinic Attendees at Risk of Stroke A Randomized Controlled Trial.csv")

# %%
df
nrow(df)
# Out:
#     Time of filling this Questionnaire Group              Hospital Number
# 1   Before Intervention                Control Group       110911
# 2   Before Intervention                Intervention Group  450571
# 3   Before Intervention                Intervention Group 1427137
# 4   Before Intervention                Intervention Group  341252
# 5   Before Intervention                Control Group      1345039
# 6   Before Intervention                Control Group       483283
# 7   Before Intervention                Intervention Group 1452144
# 8   Before Intervention                Control Group      1275633
# 9   Before Intervention                Intervention Group 1464473
# 10  Before Intervention                Intervention Group 1437546
# 11  Before Intervention                Control Group      1203358
# 12  Before Intervention                Control Group      1191066
# 13  Before Intervention                Control Group      1464380
# ...

# %%
summary(df)
# Out:
#  Time of filling this Questionnaire    Group           Hospital Number
#  Length:266                         Length:266         Min.   :  13497
#  Class :character                   Class :character   1st Qu.: 990500
#  Mode  :character                   Mode  :character   Median :1296936
#                                                        Mean   :1131883
#                                                        3rd Qu.:1444369
#                                                        Max.   :1468164
#  Main Phone Number       Age           Gender          Marital Status
#  Length:266         Min.   :29.00   Length:266         Length:266
#  Class :character   1st Qu.:52.00   Class :character   Class :character
#  Mode  :character   Median :60.50   Mode  :character   Mode  :character
#                     Mean   :59.19
#                     3rd Qu.:67.00
#                     Max.   :84.00
#    Religion          Ethnicity         Highest Level of Education
# ...

# %%
df_before <- df[df$"Time of filling this Questionnaire" == 'Before Intervention', ]

summary (df_before)
colnames(df_before) <- c("BEFORE_Questionnaire_Filling_time",
                         "BEFORE_Group",
                         "Hospital_Number",
                         "BEFORE_Phone",
                         "BEFORE_Age",
                         "BEFORE_Gender",
                         "BEFORE_Marital_status",
                         "BEFORE_Religion",
                         "BEFORE_Ethnicity",
                         "BEFORE_Highest_level_of_education",
                         "BEFORE_Medical_condition",
                         "BEFORE_Family_history",
                         "BEFORE_Which_family_member",
                         "BEFORE_Comorbidities",
                         "BEFORE_Risk_factors",
                         "BEFORE_Drug_history",
                         "BEFORE_Do_you_sometimes_forget_medication",
                         "BEFORE_Were_there_days_you_didnt_take_medication",
                         "BEFORE_Cut_medication_without_telling_doctor",
                         "BEFORE_Forget_medication_on_travel",
                         "BEFORE_Took_medication_yesterday_last",
                         "BEFORE_Stop_medication_when_symptoms_control",
                         "BEFORE_Hassle_sticking_to_treatment_plan",
                         "BEFORE_Often_difficulty_remembering_take_medication",
                         "BEFORE_MOBILITY",
                         "BEFORE_SELF_CARE",
                         "BEFORE_USUAL_ACTIVITIES",
                         "BEFORE_PAIN_DISCOMFORT",
                         "BEFORE_ANXIETY_DEPRESSION",
                         "BEFORE_HEALTH_SCORE_TODAY",
                         "BEFORE_Regular_exercise_reduces_stroke_risk",
                         "BEFORE_Weight_loss_reduces_stroke_risk",
                         "BEFORE_Abstinence_from_smoking_reduces_stroke_risk",
                         "BEFORE_Appropriate_hypertension_treatment_reduces_stroke_risk",
                         "BEFORE_Appropriate_diabetes_mellitus_treatment_reduces_stroke_risk",
                         "BEFORE_Reduced_fatty_foods_consumption_reduces_stroke_risk",
                         "BEFORE_Regular_fruits_vegetables_reduces_stroke_risk",
                         "BEFORE_Low_salt_diet_reduces_stroke_risk",
                         "BEFORE_Avoidance_excessive_alcohol_reduces_stroke_risk",
                         "BEFORE_Females_should_avoid_COC",
                         "BEFORE_Appropriate_treatement_heart_disease_reduces_stroke_risk",
                         "BEFORE_Regular_blood_donation_reduces_stroke_risk",
                         "BEFORE_Regular_blood_pressure_check_reduces_stroke_risk",
                         "BEFORE_Attend_follow_up_clinic_visit",
                         "BEFORE_Take_prescribed_hypertension_diabetes_medications",
                         "BEFORE_Do_home_blood_pressure_monitoring",
                         "BEFORE_Do_home_blood_sugar_monitoring",
                         "BEFORE_Take_cholesterol_lowering_drugs",
                         "BEFORE_Take_low_dose_aspirin",
                         "BEFORE_Eat_fruits_vegetables",
                         "BEFORE_Eat_foods_low_saturated_fat",
                         "BEFORE_Reduce_salt_intake",
                         "BEFORE_Engage_in_weight_control_measures",
                         "BEFORE_Reduce_alcohol_intake",
                         "BEFORE_Avoid_oral_contraceptives_women",
                         "BEFORE_Avoid_quit_smoking",
                         "BEFORE_Take_prescribed_heart_disease_medication",
                         "BEFORE_Donate_blood_regularly"
                        )


summary (df_before)
head(df_before)
nrow(df_before)
# Out:
#  Time of filling this Questionnaire    Group           Hospital Number
#  Length:150                         Length:150         Min.   :  13497
#  Class :character                   Class :character   1st Qu.:1014880
#  Mode  :character                   Mode  :character   Median :1312925
#                                                        Mean   :1160380
#                                                        3rd Qu.:1444893
#                                                        Max.   :1468164
#  Main Phone Number       Age           Gender          Marital Status
#  Length:150         Min.   :29.00   Length:150         Length:150
#  Class :character   1st Qu.:52.00   Class :character   Class :character
#  Mode  :character   Median :60.00   Mode  :character   Mode  :character
#                     Mean   :58.51
#                     3rd Qu.:67.00
#                     Max.   :84.00
#    Religion          Ethnicity         Highest Level of Education
# ...

# %%
df_after <- df[df$"Time of filling this Questionnaire" == 'After Intevention', ]

df_after

nrow(df_after)
# Out:
#     Time of filling this Questionnaire Group              Hospital Number
# 1   After Intevention                  Intervention Group 1463103
# 2   After Intevention                  Intervention Group 1075283
# 3   After Intevention                  Intervention Group 1428958
# 4   After Intevention                  Intervention Group  743127
# 5   After Intevention                  Intervention Group 1270206
# 6   After Intevention                  Intervention Group 1352592
# 7   After Intevention                  Intervention Group  743127
# 8   After Intevention                  Intervention Group 1286438
# 9   After Intevention                  Intervention Group 1463954
# 10  After Intevention                  Intervention Group 1464671
# 11  After Intevention                  Control Group      1345039
# 12  After Intevention                  Intervention Group 1443579
# 13  After Intevention                  Intervention Group 1092912
# ...

# %%
summary(df_after)

summary(df_after)
colnames(df_after) <- c("AFTER_Questionnaire_Filling_time",
                         "AFTER_Group",
                         "Hospital_Number",
                         "AFTER_Phone",
                         "AFTER_Age",
                         "AFTER_Gender",
                         "AFTER_Marital_status",
                         "AFTER_Religion",
                         "AFTER_Ethnicity",
                         "AFTER_Highest_level_of_education",
                         "AFTER_Medical_condition",
                         "AFTER_Family_history",
                         "AFTER_Which_family_member",
                         "AFTER_Comorbidities",
                         "AFTER_Risk_factors",
                         "AFTER_Drug_history",
                         "AFTER_Do_you_sometimes_forget_medication",
                         "AFTER_Were_there_days_you_didnt_take_medication",
                         "AFTER_Cut_medication_without_telling_doctor",
                         "AFTER_Forget_medication_on_travel",
                         "AFTER_Took_medication_yesterday_last",
                         "AFTER_Stop_medication_when_symptoms_control",
                         "AFTER_Hassle_sticking_to_treatment_plan",
                         "AFTER_Often_difficulty_remembering_take_medication",
                         "AFTER_MOBILITY",
                         "AFTER_SELF_CARE",
                         "AFTER_USUAL_ACTIVITIES",
                         "AFTER_PAIN_DISCOMFORT",
                         "AFTER_ANXIETY_DEPRESSION",
                         "AFTER_HEALTH_SCORE_TODAY",
                         "AFTER_Regular_exercise_reduces_stroke_risk",
                         "AFTER_Weight_loss_reduces_stroke_risk",
                         "AFTER_Abstinence_from_smoking_reduces_stroke_risk",
                         "AFTER_Appropriate_hypertension_treatment_reduces_stroke_risk",
                         "AFTER_Appropriate_diabetes_mellitus_treatment_reduces_stroke_risk",
                         "AFTER_Reduced_fatty_foods_consumption_reduces_stroke_risk",
                         "AFTER_Regular_fruits_vegetables_reduces_stroke_risk",
                         "AFTER_Low_salt_diet_reduces_stroke_risk",
                         "AFTER_Avoidance_excessive_alcohol_reduces_stroke_risk",
                         "AFTER_Females_should_avoid_COC",
                         "AFTER_Appropriate_treatement_heart_disease_reduces_stroke_risk",
                         "AFTER_Regular_blood_donation_reduces_stroke_risk",
                         "AFTER_Regular_blood_pressure_check_reduces_stroke_risk",
                         "AFTER_Attend_follow_up_clinic_visit",
                         "AFTER_Take_prescribed_hypertension_diabetes_medications",
                         "AFTER_Do_home_blood_pressure_monitoring",
                         "AFTER_Do_home_blood_sugar_monitoring",
                         "AFTER_Take_cholesterol_lowering_drugs",
                         "AFTER_Take_low_dose_aspirin",
                         "AFTER_Eat_fruits_vegetables",
                         "AFTER_Eat_foods_low_saturated_fat",
                         "AFTER_Reduce_salt_intake",
                         "AFTER_Engage_in_weight_control_measures",
                         "AFTER_Reduce_alcohol_intake",
                         "AFTER_Avoid_oral_contraceptives_women",
                         "AFTER_Avoid_quit_smoking",
                         "AFTER_Take_prescribed_heart_disease_medication",
                         "AFTER_Donate_blood_regularly"
                        )


summary (df_after)
head(df_after)
nrow(df_after)
# Out:
#  Time of filling this Questionnaire    Group           Hospital Number
#  Length:116                         Length:116         Min.   : 110911
#  Class :character                   Class :character   1st Qu.: 928607
#  Mode  :character                   Mode  :character   Median :1274443
#                                                        Mean   :1095034
#                                                        3rd Qu.:1442950
#                                                        Max.   :1468164
#  Main Phone Number       Age           Gender          Marital Status
#  Length:116         Min.   :29.00   Length:116         Length:116
#  Class :character   1st Qu.:53.00   Class :character   Class :character
#  Mode  :character   Median :63.00   Mode  :character   Mode  :character
#                     Mean   :60.08
#                     3rd Qu.:67.25
#                     Max.   :84.00
#    Religion          Ethnicity         Highest Level of Education
# ...

# %%
sum(duplicated(df_before$Hospital_Number))
sum(duplicated(df_after$Hospital_Number))
# Out:
# [1] 0
# [1] 1

# %%
duplicated(df_after$Hospital_Number)
# Out:
#   [1] FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE
#  [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE

# %%
df_after[duplicated(df_after$Hospital_Number), ]
# Out:
#   AFTER_Questionnaire_Filling_time AFTER_Group        Hospital_Number
# 1 After Intevention                Intervention Group 743127
#   AFTER_Phone AFTER_Age AFTER_Gender AFTER_Marital_status AFTER_Religion
# 1 08034155136 68        Female       Married              Christianity
#   AFTER_Ethnicity AFTER_Highest_level_of_education ...
# 1 Ibo             Secondary                        ...
#   AFTER_Take_low_dose_aspirin AFTER_Eat_fruits_vegetables
# 1 Rarely                      Always
#   AFTER_Eat_foods_low_saturated_fat AFTER_Reduce_salt_intake
# 1 Always                            Always
#   AFTER_Engage_in_weight_control_measures AFTER_Reduce_alcohol_intake
# 1 Often                                   Always
#   AFTER_Avoid_oral_contraceptives_women AFTER_Avoid_quit_smoking
# 1 Always                                Always
#   AFTER_Take_prescribed_heart_disease_medication AFTER_Donate_blood_regularly
# 1 Always                                         Never

# %%
df_after[df_after$Hospital_Number == '743127', ]
# Out:
#   AFTER_Questionnaire_Filling_time AFTER_Group        Hospital_Number
# 1 After Intevention                Intervention Group 743127
# 2 After Intevention                Intervention Group 743127
#   AFTER_Phone AFTER_Age AFTER_Gender AFTER_Marital_status AFTER_Religion
# 1 08034155136 68        Female       Married              Christianity
# 2 08034155136 68        Female       Married              Christianity
#   AFTER_Ethnicity AFTER_Highest_level_of_education ...
# 1 Ibo             Secondary                        ...
# 2 Ibo             Secondary                        ...
#   AFTER_Take_low_dose_aspirin AFTER_Eat_fruits_vegetables
# 1 Sometimes                   Always
# 2 Rarely                      Always
#   AFTER_Eat_foods_low_saturated_fat AFTER_Reduce_salt_intake
# 1 Often                             Always
# 2 Always                            Always
#   AFTER_Engage_in_weight_control_measures AFTER_Reduce_alcohol_intake
# ...

# %%
## there are 2 entries with hospital number 743127
## remove both entries are there conflicting entries on certain columns

df_after_nodups <- df_after[!(df_after$Hospital_Number %in% "743127"),]

df_after_nodups
nrow(df_after_nodups)
# Out:
#     AFTER_Questionnaire_Filling_time AFTER_Group        Hospital_Number
# 1   After Intevention                Intervention Group 1463103
# 2   After Intevention                Intervention Group 1075283
# 3   After Intevention                Intervention Group 1428958
# 4   After Intevention                Intervention Group 1270206
# 5   After Intevention                Intervention Group 1352592
# 6   After Intevention                Intervention Group 1286438
# 7   After Intevention                Intervention Group 1463954
# 8   After Intevention                Intervention Group 1464671
# 9   After Intevention                Control Group      1345039
# 10  After Intevention                Intervention Group 1443579
# 11  After Intevention                Intervention Group 1092912
# 12  After Intevention                Intervention Group 1213565
# 13  After Intevention                Intervention Group 1109324
# 14  After Intevention                Intervention Group 1345838
# ...

# %%
# merge df_before and df_after_nodups dataframes using Hospital Number

merged_df <- merge(df_before, df_after_nodups, by="Hospital_Number", all.x = T)
nrow(merged_df)
merged_df

require(dplyr)
## remove phone number, hospital number, 
## remove AFTER VARIABLES -- Age, Gender, Marital_status, ethnicity, education,
### religion, medical condition, family history, which family member has history, 
#### drug history risk factors


to_drop <- c("BEFORE_Phone", "AFTER_Phone", "Hospital_Number",
            "AFTER_Age", "AFTER_Gender", "AFTER_Marital_status",
            "AFTER_Religion", "AFTER_Ethnicity", "AFTER_Highest_level_of_education",
            "AFTER_Medical_condition", "AFTER_Family_history", "AFTER_Which_family_member",
            "AFTER_Comorbidities", "AFTER_Risk_factors", "AFTER_Drug_history")

after_prune_merged_df <- select(merged_df, -to_drop)
after_prune_merged_df
ncol(merged_df)
ncol(after_prune_merged_df)
# Out:
# [1] 150
#     Hospital_Number BEFORE_Questionnaire_Filling_time BEFORE_Group
# 1    13497          Before Intervention               Intervention Group
# 2   104436          Before Intervention               Control Group
# 3   110911          Before Intervention               Control Group
# 4   146361          Before Intervention               Control Group
# 5   150787          Before Intervention               Control Group
# 6   154915          Before Intervention               Control Group
# 7   320834          Before Intervention               Control Group
# 8   330182          Before Intervention               Control Group
# 9   341252          Before Intervention               Intervention Group
# 10  343661          Before Intervention               Intervention Group
# 11  368350          Before Intervention               Control Group
# 12  372704          Before Intervention               Control Group
# ...

# %%
nrow(after_prune_merged_df[after_prune_merged_df$AFTER_Questionnaire_Filling_time == "NA",])
# Out:
# [1] 48

# %% [markdown]
# 48 participants were lost to follow up

# %%
summary(after_prune_merged_df)
ncol(after_prune_merged_df)
# Out:
#  BEFORE_Questionnaire_Filling_time BEFORE_Group         BEFORE_Age
#  Length:150                        Length:150         Min.   :29.00
#  Class :character                  Class :character   1st Qu.:52.00
#  Mode  :character                  Mode  :character   Median :60.00
#                                                       Mean   :58.51
#                                                       3rd Qu.:67.00
#                                                       Max.   :84.00
#
#  BEFORE_Gender      BEFORE_Marital_status BEFORE_Religion    BEFORE_Ethnicity
#  Length:150         Length:150            Length:150         Length:150
#  Class :character   Class :character      Class :character   Class :character
#  Mode  :character   Mode  :character      Mode  :character   Mode  :character
#
#
#
#
#  BEFORE_Highest_level_of_education BEFORE_Medical_condition
#  Length:150                        Length:150
#  Class :character                  Class :character
# ...

# %%
#### impute missing variables AFTER intervention (due to loss to follow up) using data collected BEFORE
##### FOR INTENTION TO TREAT ANALYSIS
#### assumption is that those lost to follow up have the same readouts BEFORE and AFTER intervention


after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Questionnaire_Filling_time = if_else(
        is.na(AFTER_Questionnaire_Filling_time), BEFORE_Questionnaire_Filling_time,
        AFTER_Questionnaire_Filling_time))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Group = if_else(
        is.na(AFTER_Group), BEFORE_Group,
        AFTER_Group))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Do_you_sometimes_forget_medication = if_else(
        is.na(AFTER_Do_you_sometimes_forget_medication), BEFORE_Do_you_sometimes_forget_medication,
        AFTER_Do_you_sometimes_forget_medication))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Were_there_days_you_didnt_take_medication = if_else(
        is.na(AFTER_Were_there_days_you_didnt_take_medication), BEFORE_Were_there_days_you_didnt_take_medication,
        AFTER_Were_there_days_you_didnt_take_medication))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Cut_medication_without_telling_doctor = if_else(
        is.na(AFTER_Cut_medication_without_telling_doctor), BEFORE_Cut_medication_without_telling_doctor,
        AFTER_Cut_medication_without_telling_doctor))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Forget_medication_on_travel = if_else(
        is.na(AFTER_Forget_medication_on_travel), BEFORE_Forget_medication_on_travel,
        AFTER_Forget_medication_on_travel))
                       
after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Took_medication_yesterday_last = if_else(
        is.na(AFTER_Took_medication_yesterday_last), BEFORE_Took_medication_yesterday_last,
        AFTER_Took_medication_yesterday_last))
 
after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Stop_medication_when_symptoms_control = if_else(
        is.na(AFTER_Stop_medication_when_symptoms_control), BEFORE_Stop_medication_when_symptoms_control,
        AFTER_Stop_medication_when_symptoms_control))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Hassle_sticking_to_treatment_plan = if_else(
        is.na(AFTER_Hassle_sticking_to_treatment_plan), BEFORE_Hassle_sticking_to_treatment_plan,
        AFTER_Hassle_sticking_to_treatment_plan))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Often_difficulty_remembering_take_medication = if_else(
        is.na(AFTER_Often_difficulty_remembering_take_medication), BEFORE_Often_difficulty_remembering_take_medication,
        AFTER_Often_difficulty_remembering_take_medication))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_MOBILITY = if_else(
        is.na(AFTER_MOBILITY), BEFORE_MOBILITY,
        AFTER_MOBILITY))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_SELF_CARE = if_else(
        is.na(AFTER_SELF_CARE), BEFORE_SELF_CARE,
        AFTER_SELF_CARE))
                                                  
after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_USUAL_ACTIVITIES = if_else(
        is.na(AFTER_USUAL_ACTIVITIES), BEFORE_USUAL_ACTIVITIES,
        AFTER_USUAL_ACTIVITIES))
   
after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_PAIN_DISCOMFORT = if_else(
        is.na(AFTER_PAIN_DISCOMFORT), BEFORE_PAIN_DISCOMFORT,
        AFTER_PAIN_DISCOMFORT))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_ANXIETY_DEPRESSION = if_else(
        is.na(AFTER_ANXIETY_DEPRESSION), BEFORE_ANXIETY_DEPRESSION,
        AFTER_ANXIETY_DEPRESSION))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_HEALTH_SCORE_TODAY = if_else(
        is.na(AFTER_HEALTH_SCORE_TODAY), BEFORE_HEALTH_SCORE_TODAY,
        AFTER_HEALTH_SCORE_TODAY))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Regular_exercise_reduces_stroke_risk = if_else(
        is.na(AFTER_Regular_exercise_reduces_stroke_risk), BEFORE_Regular_exercise_reduces_stroke_risk,
        AFTER_Regular_exercise_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Weight_loss_reduces_stroke_risk = if_else(
        is.na(AFTER_Weight_loss_reduces_stroke_risk), BEFORE_Weight_loss_reduces_stroke_risk,
        AFTER_Weight_loss_reduces_stroke_risk))
                                                                      
after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Abstinence_from_smoking_reduces_stroke_risk = if_else(
        is.na(AFTER_Abstinence_from_smoking_reduces_stroke_risk), BEFORE_Abstinence_from_smoking_reduces_stroke_risk,
        AFTER_Abstinence_from_smoking_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Appropriate_hypertension_treatment_reduces_stroke_risk = if_else(
        is.na(AFTER_Appropriate_hypertension_treatment_reduces_stroke_risk), BEFORE_Appropriate_hypertension_treatment_reduces_stroke_risk,
        AFTER_Appropriate_hypertension_treatment_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Appropriate_diabetes_mellitus_treatment_reduces_stroke_risk = if_else(
        is.na(AFTER_Appropriate_diabetes_mellitus_treatment_reduces_stroke_risk), BEFORE_Appropriate_diabetes_mellitus_treatment_reduces_stroke_risk,
        AFTER_Appropriate_diabetes_mellitus_treatment_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Reduced_fatty_foods_consumption_reduces_stroke_risk = if_else(
        is.na(AFTER_Reduced_fatty_foods_consumption_reduces_stroke_risk), BEFORE_Reduced_fatty_foods_consumption_reduces_stroke_risk,
        AFTER_Reduced_fatty_foods_consumption_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Regular_fruits_vegetables_reduces_stroke_risk = if_else(
        is.na(AFTER_Regular_fruits_vegetables_reduces_stroke_risk), BEFORE_Regular_fruits_vegetables_reduces_stroke_risk,
        AFTER_Regular_fruits_vegetables_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Low_salt_diet_reduces_stroke_risk = if_else(
        is.na(AFTER_Low_salt_diet_reduces_stroke_risk), BEFORE_Low_salt_diet_reduces_stroke_risk,
        AFTER_Low_salt_diet_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Avoidance_excessive_alcohol_reduces_stroke_risk = if_else(
        is.na(AFTER_Avoidance_excessive_alcohol_reduces_stroke_risk), BEFORE_Avoidance_excessive_alcohol_reduces_stroke_risk,
        AFTER_Avoidance_excessive_alcohol_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Females_should_avoid_COC = if_else(
        is.na(AFTER_Females_should_avoid_COC), BEFORE_Females_should_avoid_COC,
        AFTER_Females_should_avoid_COC))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Appropriate_treatement_heart_disease_reduces_stroke_risk = if_else(
        is.na(AFTER_Appropriate_treatement_heart_disease_reduces_stroke_risk), BEFORE_Appropriate_treatement_heart_disease_reduces_stroke_risk,
        AFTER_Appropriate_treatement_heart_disease_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Regular_blood_donation_reduces_stroke_risk = if_else(
        is.na(AFTER_Regular_blood_donation_reduces_stroke_risk), BEFORE_Regular_blood_donation_reduces_stroke_risk,
        AFTER_Regular_blood_donation_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Regular_blood_pressure_check_reduces_stroke_risk = if_else(
        is.na(AFTER_Regular_blood_pressure_check_reduces_stroke_risk), BEFORE_Regular_blood_pressure_check_reduces_stroke_risk,
        AFTER_Regular_blood_pressure_check_reduces_stroke_risk))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Attend_follow_up_clinic_visit = if_else(
        is.na(AFTER_Attend_follow_up_clinic_visit), BEFORE_Attend_follow_up_clinic_visit,
        AFTER_Attend_follow_up_clinic_visit))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Take_prescribed_hypertension_diabetes_medications = if_else(
        is.na(AFTER_Take_prescribed_hypertension_diabetes_medications), BEFORE_Take_prescribed_hypertension_diabetes_medications,
        AFTER_Take_prescribed_hypertension_diabetes_medications))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Do_home_blood_pressure_monitoring = if_else(
        is.na(AFTER_Do_home_blood_pressure_monitoring), BEFORE_Do_home_blood_pressure_monitoring,
        AFTER_Do_home_blood_pressure_monitoring))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Do_home_blood_sugar_monitoring = if_else(
        is.na(AFTER_Do_home_blood_sugar_monitoring), BEFORE_Do_home_blood_sugar_monitoring,
        AFTER_Do_home_blood_sugar_monitoring))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Take_cholesterol_lowering_drugs = if_else(
        is.na(AFTER_Take_cholesterol_lowering_drugs), BEFORE_Take_cholesterol_lowering_drugs,
        AFTER_Take_cholesterol_lowering_drugs))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Take_low_dose_aspirin = if_else(
        is.na(AFTER_Take_low_dose_aspirin), BEFORE_Take_low_dose_aspirin,
        AFTER_Take_low_dose_aspirin))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Eat_fruits_vegetables = if_else(
        is.na(AFTER_Eat_fruits_vegetables), BEFORE_Eat_fruits_vegetables,
        AFTER_Eat_fruits_vegetables))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Eat_foods_low_saturated_fat = if_else(
        is.na(AFTER_Eat_foods_low_saturated_fat), BEFORE_Eat_foods_low_saturated_fat,
        AFTER_Eat_foods_low_saturated_fat))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Reduce_salt_intake = if_else(
        is.na(AFTER_Reduce_salt_intake), BEFORE_Reduce_salt_intake,
        AFTER_Reduce_salt_intake)) 
 
after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Engage_in_weight_control_measures = if_else(
        is.na(AFTER_Engage_in_weight_control_measures), BEFORE_Engage_in_weight_control_measures,
        AFTER_Engage_in_weight_control_measures)) 

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Reduce_alcohol_intake = if_else(
        is.na(AFTER_Reduce_alcohol_intake), BEFORE_Reduce_alcohol_intake,
        AFTER_Reduce_alcohol_intake)) 

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Avoid_oral_contraceptives_women = if_else(
        is.na(AFTER_Avoid_oral_contraceptives_women), BEFORE_Avoid_oral_contraceptives_women,
        AFTER_Avoid_oral_contraceptives_women)) 
 
after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Avoid_quit_smoking = if_else(
        is.na(AFTER_Avoid_quit_smoking), BEFORE_Avoid_quit_smoking,
        AFTER_Avoid_quit_smoking)) 

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Take_prescribed_heart_disease_medication = if_else(
        is.na(AFTER_Take_prescribed_heart_disease_medication), BEFORE_Take_prescribed_heart_disease_medication,
        AFTER_Take_prescribed_heart_disease_medication))

after_prune_merged_df <- after_prune_merged_df %>% 
    mutate(AFTER_Donate_blood_regularly = if_else(
        is.na(AFTER_Donate_blood_regularly), BEFORE_Donate_blood_regularly,
        AFTER_Donate_blood_regularly))

after_prune_merged_df
# Out:
#     BEFORE_Questionnaire_Filling_time BEFORE_Group       BEFORE_Age
# 1   Before Intervention               Intervention Group 58
# 2   Before Intervention               Control Group      52
# 3   Before Intervention               Control Group      68
# 4   Before Intervention               Control Group      60
# 5   Before Intervention               Control Group      71
# 6   Before Intervention               Control Group      65
# 7   Before Intervention               Control Group      65
# 8   Before Intervention               Control Group      35
# 9   Before Intervention               Intervention Group 77
# 10  Before Intervention               Intervention Group 67
# 11  Before Intervention               Control Group      84
# 12  Before Intervention               Control Group      71
# 13  Before Intervention               Control Group      68
# 14  Before Intervention               Control Group      63
# 15  Before Intervention               Intervention Group 75
# ...

# %%
## number of those left to follow up 
#### now imputed with data collected before intervention

nrow(after_prune_merged_df[after_prune_merged_df$AFTER_Questionnaire_Filling_time == "Before Intervention",])
after_prune_merged_df[after_prune_merged_df$AFTER_Questionnaire_Filling_time == "Before Intervention",]
# Out:
# [1] 48
#     BEFORE_Questionnaire_Filling_time BEFORE_Group       BEFORE_Age
# 1   Before Intervention               Intervention Group 58
# 2   Before Intervention               Control Group      52
# 8   Before Intervention               Control Group      35
# 15  Before Intervention               Intervention Group 75
# 18  Before Intervention               Control Group      70
# 19  Before Intervention               Control Group      75
# 21  Before Intervention               Intervention Group 68
# 27  Before Intervention               Intervention Group 53
# 30  Before Intervention               Control Group      67
# 31  Before Intervention               Intervention Group 52
# 32  Before Intervention               Intervention Group 53
# 33  Before Intervention               Intervention Group 54
# 34  Before Intervention               Intervention Group 61
# 40  Before Intervention               Intervention Group 63
# ...

# %%
write.csv(after_prune_merged_df, "stroke_sms_merged.csv", row.names=FALSE)
